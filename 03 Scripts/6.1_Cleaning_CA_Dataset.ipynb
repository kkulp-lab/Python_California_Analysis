# %% [markdown]
# ## Exercise 6.1
#
# Starting to familiarize and clean the california census tract data set. The data set contains information on pollutants and demogrpahics on census tract areas in CA, with scores that take into account the factors provided.

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Set path

path = r'C:\Users\Jenna\Desktop\Data Course\Part 6\Raw Data'

# %%
# Import data

df = pd.read_csv(os.path.join(path, 'CA_data.csv'), index_col = False)

# %%
# check shape

df.shape
# Out:
# (8035, 57)

# %%
# check head
pd.options.display.max_columns = None
df.head()
# Out:
#    Census Tract  Total Population California County    ZIP  \
# 0    6019001100              3174           Fresno   93706
# 1    6071001600              6133    San Bernardino  91761
# 2    6019000200              3167           Fresno   93706
# 3    6077000801              6692       San Joaquin  95203
# 4    6019001500              2206           Fresno   93725
#
#   Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 0                                            Fresno -119.781696  36.709695
# 1                                           Ontario -117.618013  34.057780
# 2                                            Fresno -119.805504  36.735491
# 3                                          Stockton -121.314524  37.940517
# 4                                            Fresno -119.717843  36.681600
#
#    CES 3.0 Score  CES 3.0 Percentile CES 3.0 \nPercentile Range  \
# 0          94.09              100.00   95-100% (highest scores)
# ...

# %% [markdown]
# ## 1. First Step:
#
# I Think that for the purpose of my analysis, I will drop the percentile and scored columns and just focus on the values, I will save the smaller dataset under a different name in case I decided to use the percentiles later. I will also drop unneeded information

# %%
# drop column
col_to_drop = [
    'CES 3.0 Score',
    'SB 535 Disadvantaged Community',
    'CES 3.0 Percentile',
    'CES 3.0 \nPercentile Range',
    'Ozone Pctl',
    'PM2.5 Pctl',
    'Diesel PM Pctl',
    'Drinking Water Pctl',
    'Pesticides Pctl',
    'Tox. Release Pctl',
    'Traffic Pctl',
    'Cleanup Sites Pctl',
    'Groundwater Threats Pctl',
    'Haz. Waste Pctl',
    'Imp. Water Bodies Pctl',
    'Solid Waste Pctl',
    'Pollution Burden Pctl',
    'Asthma Pctl',
    'Low Birth Weight Pctl',
    'Cardiovascular Disease Pctl',
    'Education Pctl',
    'Linguistic Isolation Pctl',
    'Poverty Pctl',
    'Unemployment Pctl',
    'Housing Burden Pctl',
    'Pop. Char. Pctl',
    'Nearby City \n(to help approximate location only)',
    'Pop. Char.',
    'Pop. Char. Score',
    'Pollution Burden',
   'Pollution Burden Score'
]

df = df.drop(columns= col_to_drop)
df.head()
# Out:
#    Census Tract  Total Population California County    ZIP   Longitude  \
# 0    6019001100              3174           Fresno   93706 -119.781696
# 1    6071001600              6133    San Bernardino  91761 -117.618013
# 2    6019000200              3167           Fresno   93706 -119.805504
# 3    6077000801              6692       San Joaquin  95203 -121.314524
# 4    6019001500              2206           Fresno   93725 -119.717843
#
#     Latitude  Ozone  PM2.5  Diesel PM  Drinking Water  Pesticides  \
# 0  36.709695  0.065  15.40     48.524          681.20        2.75
# 1  34.057780  0.062  13.31     38.556          904.66        1.37
# 2  36.735491  0.062  15.40     47.445          681.20        3.03
# 3  37.940517  0.046  12.54     24.117          278.76       12.93
# 4  36.681600  0.065  15.40     18.846         1000.24     3518.41
#
#    Tox. Release  Traffic  Cleanup Sites  Groundwater Threats  Haz. Waste  \
# ...

# %%
# Check the new shape of my dataframe

df.shape
# Out:
# (8035, 26)

# %%
df.describe()
# Out:
#        Census Tract  Total Population           ZIP    Longitude     Latitude  \
# count  8.035000e+03       8035.000000   8035.000000  8035.000000  8035.000000
# mean   6.054896e+09       4636.459988  92836.574611  -119.409318    35.495893
# std    2.652280e+07       1972.587602   3445.177594     1.976336     2.086016
# min    6.001400e+09          0.000000     32.000000  -124.297889    32.547376
# 25%    6.037265e+09       3358.000000  91602.000000  -121.518410    33.924145
# 50%    6.059053e+09       4413.000000  92691.000000  -118.429194    34.206624
# 75%    6.073016e+09       5656.500000  94558.000000  -117.924814    37.634021
# max    6.115041e+09      37452.000000  96161.000000  -114.306484    41.946648
#
#              Ozone        PM2.5    Diesel PM  Drinking Water    Pesticides  \
# count  8035.000000  8016.000000  8035.000000     8017.000000   8035.000000
# mean      0.047430    10.377904    19.196064      472.372294    313.973556
# ...

# %% [markdown]
# # 2nd Step: Data Cleaning
#
# Check data types, check for mixed columns

# %%
df.dtypes
# Out:
# Census Tract                int64
# Total Population            int64
# California County          object
# ZIP                         int64
# Longitude                 float64
# Latitude                  float64
# Ozone                     float64
# PM2.5                     float64
# Diesel PM                 float64
# Drinking Water            float64
# Pesticides                float64
# Tox. Release              float64
# Traffic                   float64
# Cleanup Sites             float64
# Groundwater Threats       float64
# Haz. Waste                float64
# Imp. Water Bodies           int64
# Solid Waste               float64
# Asthma                    float64
# Low Birth Weight          float64
# Cardiovascular Disease    float64
# Education                 float64
# Linguistic Isolation      float64
# Poverty                   float64
# Unemployment              float64
# Housing Burden            float64
# dtype: object

# %%
# check for mixed columns

for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df[weird]) > 0:
        print (col)

# %% [markdown]
# ## Check for missing data

# %%
# check for missing data 
df.isnull().sum()
# Out:
# Census Tract                0
# Total Population            0
# California County           0
# ZIP                         0
# Longitude                   0
# Latitude                    0
# Ozone                       0
# PM2.5                      19
# Diesel PM                   0
# Drinking Water             18
# Pesticides                  0
# Tox. Release                0
# Traffic                    56
# Cleanup Sites               0
# Groundwater Threats         0
# Haz. Waste                  0
# Imp. Water Bodies           0
# Solid Waste                 0
# Asthma                      0
# Low Birth Weight          222
# Cardiovascular Disease      0
# Education                  96
# Linguistic Isolation      242
# Poverty                    79
# Unemployment              155
# Housing Burden            157
# dtype: int64

# %% [markdown]
# ## Some data is missing or not applicable, I will leave it unchanged for now

# %% [markdown]
# ## Check for duplicate data

# %%
# find duplicates in the data

df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Census Tract, Total Population, California County, ZIP, Longitude, Latitude, Ozone, PM2.5, Diesel PM, Drinking Water, Pesticides, Tox. Release, Traffic, Cleanup Sites, Groundwater Threats, Haz. Waste, Imp. Water Bodies, Solid Waste, Asthma, Low Birth Weight, Cardiovascular Disease, Education, Linguistic Isolation, Poverty, Unemployment, Housing Burden]
# Index: []

# %% [markdown]
# # Export data

# %%
df.to_csv(os.path.join(path, 'NEW_CA_data.csv'))
